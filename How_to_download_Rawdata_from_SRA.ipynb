# %% [markdown]
# Illumina data can be downloaded from SRA using the following workflow.
#
# It will requre the [SRA-toolkit](http://www.ncbi.nlm.nih.gov/Traces/sra/?view=toolkit_doc) program `fastq-dump` to be installed on your machine and in your path.
#
# If the necessary program is not yet present in your system you can get it as follows:

# %%
# !pwd
# Out:
# /home/working

# %% [markdown]
# __Download the latest version of sratoolkit__

# %%
# %%bash
#
# mkdir SRA-toolkit
# cd SRA-toolkit
#
# wget ftp://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz
#
# #decompress the archive
# tar -xzf sratoolkit.current-centos_linux64.tar.gz

# %%
# !ls SRA-toolkit/
# Out:
# sratoolkit.2.9.2-centos_linux64  sratoolkit.current-centos_linux64.tar.gz

# %%
# !pwd
# Out:
# /home/working

# %%
# %%bash
#
#
# #add the fastq-dump executable to your PATH (may require sudo)
# cp SRA-toolkit/sratoolkit.2.9.2-centos_linux64/bin/fastq-dump /usr/local/bin
#
# #remove SRA toolkit files that are not required
#
# rm -rf SRA-toolkit/

# %% [markdown]
# The following commmand will read through the file Sample_accessions.tsv (see [here](https://github.com/HullUni-bioinformatics/Handley_et_al_2018/blob/master/supplementary_data/Sample_accessions.tsv)) and download the relevant raw read files from SRA basd on the accessions provided in column 3 of the file. It will then rename the files according to the sampleID (column 1) and the marker (column 2).Then save the raw data to 'raw_data' folder

# %%
# !mkdir raw_reads

# %%
cd raw_reads/
# Out:
# /home/working/raw_reads

# %%
# %%bash
#
# for s in $(cat ../supplementary_data/Sample_accessions.tsv | sed 's/\t/,/g' | grep "SRA_accession" -v)
# do
#     id=$(echo $s | cut -d "," -f 1)
#     accession=$(echo $s | cut -d "," -f 3)
#     marker=$(echo $s | cut -d "," -f 2)
#     echo -e "$id\t$accession\t$marker"
#     fastq-dump --split-files --gzip --defline-seq '@$ac-$sn/$ri' --defline-qual '+' $accession
#     mv $accession\_1.fastq.gz $id-$marker\_R1.fastq.gz
#     mv $accession\_2.fastq.gz $id-$marker\_R2.fastq.gz
# done

# %% [markdown]
# __Double check if all files are there.__

# %%
# !ls
# Out:
# WOF01_summer-12S_R1.fastq.gz	   WOF41_summer-Cytb_R1.fastq.gz
# WOF01_summer-12S_R2.fastq.gz	   WOF41_summer-Cytb_R2.fastq.gz
# WOF01_summer-Cytb_R1.fastq.gz	   WOF42_summer-12S_R1.fastq.gz
# WOF01_summer-Cytb_R2.fastq.gz	   WOF42_summer-12S_R2.fastq.gz
# WOF01_winter-12S_R1.fastq.gz	   WOF42_summer-Cytb_R1.fastq.gz
# WOF01_winter-12S_R2.fastq.gz	   WOF42_summer-Cytb_R2.fastq.gz
# WOF01_winter-Cytb_R1.fastq.gz	   WOF42_winter-12S_R1.fastq.gz
# WOF01_winter-Cytb_R2.fastq.gz	   WOF42_winter-12S_R2.fastq.gz
# WOF02_summer-12S_R1.fastq.gz	   WOF42_winter-Cytb_R1.fastq.gz
# WOF02_summer-12S_R2.fastq.gz	   WOF42_winter-Cytb_R2.fastq.gz
# WOF02_summer-Cytb_R1.fastq.gz	   WOF43_summer-12S_R1.fastq.gz
# WOF02_summer-Cytb_R2.fastq.gz	   WOF43_summer-12S_R2.fastq.gz
# WOF02_winter-12S_R1.fastq.gz	   WOF43_summer-Cytb_R1.fastq.gz
# WOF02_winter-12S_R2.fastq.gz	   WOF43_summer-Cytb_R2.fastq.gz
# WOF02_winter-Cytb_R1.fastq.gz	   WOF43_winter-12S_R1.fastq.gz
# WOF02_winter-Cytb_R2.fastq.gz	   WOF43_winter-12S_R2.fastq.gz
# WOF03_summer-12S_R1.fastq.gz	   WOF43_winter-Cytb_R1.fastq.gz
# WOF03_summer-12S_R2.fastq.gz	   WOF43_winter-Cytb_R2.fastq.gz
# WOF03_summer-Cytb_R1.fastq.gz	   WOF44_summer-12S_R1.fastq.gz
# WOF03_summer-Cytb_R2.fastq.gz	   WOF44_summer-12S_R2.fastq.gz
# WOF03_winter-12S_R1.fastq.gz	   WOF44_summer-Cytb_R1.fastq.gz
# WOF03_winter-12S_R2.fastq.gz	   WOF44_summer-Cytb_R2.fastq.gz
# WOF03_winter-Cytb_R1.fastq.gz	   WOF44_winter-12S_R1.fastq.gz
# WOF03_winter-Cytb_R2.fastq.gz	   WOF44_winter-12S_R2.fastq.gz
# WOF04_summer-12S_R1.fastq.gz	   WOF44_winter-Cytb_R1.fastq.gz
# WOF04_summer-12S_R2.fastq.gz	   WOF44_winter-Cytb_R2.fastq.gz
# WOF04_summer-Cytb_R1.fastq.gz	   WOF45_summer-12S_R1.fastq.gz
# WOF04_summer-Cytb_R2.fastq.gz	   WOF45_summer-12S_R2.fastq.gz
# WOF04_winter-12S_R1.fastq.gz	   WOF45_summer-Cytb_R1.fastq.gz
# WOF04_winter-12S_R2.fastq.gz	   WOF45_summer-Cytb_R2.fastq.gz
# WOF04_winter-Cytb_R1.fastq.gz	   WOF45_winter-12S_R1.fastq.gz
# WOF04_winter-Cytb_R2.fastq.gz	   WOF45_winter-12S_R2.fastq.gz
# WOF05_summer-12S_R1.fastq.gz	   WOF45_winter-Cytb_R1.fastq.gz
# WOF05_summer-12S_R2.fastq.gz	   WOF45_winter-Cytb_R2.fastq.gz
# WOF05_summer-Cytb_R1.fastq.gz	   WOF46_summer-12S_R1.fastq.gz
# WOF05_summer-Cytb_R2.fastq.gz	   WOF46_summer-12S_R2.fastq.gz
# WOF05_winter-12S_R1.fastq.gz	   WOF46_summer-Cytb_R1.fastq.gz
# WOF05_winter-12S_R2.fastq.gz	   WOF46_summer-Cytb_R2.fastq.gz
# WOF05_winter-Cytb_R1.fastq.gz	   WOF46_winter-12S_R1.fastq.gz
# WOF05_winter-Cytb_R2.fastq.gz	   WOF46_winter-12S_R2.fastq.gz
# WOF06_summer-12S_R1.fastq.gz	   WOF46_winter-Cytb_R1.fastq.gz
# WOF06_summer-12S_R2.fastq.gz	   WOF46_winter-Cytb_R2.fastq.gz
# WOF06_summer-Cytb_R1.fastq.gz	   WOF47_summer-12S_R1.fastq.gz
# WOF06_summer-Cytb_R2.fastq.gz	   WOF47_summer-12S_R2.fastq.gz
# WOF06_winter-12S_R1.fastq.gz	   WOF47_summer-Cytb_R1.fastq.gz
# WOF06_winter-12S_R2.fastq.gz	   WOF47_summer-Cytb_R2.fastq.gz
# WOF06_winter-Cytb_R1.fastq.gz	   WOF47_winter-12S_R1.fastq.gz
# WOF06_winter-Cytb_R2.fastq.gz	   WOF47_winter-12S_R2.fastq.gz
# WOF07_summer-12S_R1.fastq.gz	   WOF47_winter-Cytb_R1.fastq.gz
# WOF07_summer-12S_R2.fastq.gz	   WOF47_winter-Cytb_R2.fastq.gz
# WOF07_summer-Cytb_R1.fastq.gz	   WOF48_summer-12S_R1.fastq.gz
# WOF07_summer-Cytb_R2.fastq.gz	   WOF48_summer-12S_R2.fastq.gz
# WOF07_winter-12S_R1.fastq.gz	   WOF48_summer-Cytb_R1.fastq.gz
# WOF07_winter-12S_R2.fastq.gz	   WOF48_summer-Cytb_R2.fastq.gz
# WOF07_winter-Cytb_R1.fastq.gz	   WOF48_winter-12S_R1.fastq.gz
# WOF07_winter-Cytb_R2.fastq.gz	   WOF48_winter-12S_R2.fastq.gz
# WOF08_summer-12S_R1.fastq.gz	   WOF48_winter-Cytb_R1.fastq.gz
# WOF08_summer-12S_R2.fastq.gz	   WOF48_winter-Cytb_R2.fastq.gz
# WOF08_summer-Cytb_R1.fastq.gz	   WOF49_summer-12S_R1.fastq.gz
# WOF08_summer-Cytb_R2.fastq.gz	   WOF49_summer-12S_R2.fastq.gz
# WOF08_winter-12S_R1.fastq.gz	   WOF49_summer-Cytb_R1.fastq.gz
# WOF08_winter-12S_R2.fastq.gz	   WOF49_summer-Cytb_R2.fastq.gz
# WOF08_winter-Cytb_R1.fastq.gz	   WOF49_winter-12S_R1.fastq.gz
# WOF08_winter-Cytb_R2.fastq.gz	   WOF49_winter-12S_R2.fastq.gz
# WOF09_summer_0m-12S_R1.fastq.gz    WOF49_winter-Cytb_R1.fastq.gz
# WOF09_summer_0m-12S_R2.fastq.gz    WOF49_winter-Cytb_R2.fastq.gz
# WOF09_summer_0m-Cytb_R1.fastq.gz   WOF50_summer-12S_R1.fastq.gz
# WOF09_summer_0m-Cytb_R2.fastq.gz   WOF50_summer-12S_R2.fastq.gz
# WOF09_summer_40m-12S_R1.fastq.gz   WOF50_summer-Cytb_R1.fastq.gz
# WOF09_summer_40m-12S_R2.fastq.gz   WOF50_summer-Cytb_R2.fastq.gz
# WOF09_summer_40m-Cytb_R1.fastq.gz  WOF50_winter-12S_R1.fastq.gz
# WOF09_summer_40m-Cytb_R2.fastq.gz  WOF50_winter-12S_R2.fastq.gz
# WOF09_summer_mid-12S_R1.fastq.gz   WOF50_winter-Cytb_R1.fastq.gz
# WOF09_summer_mid-12S_R2.fastq.gz   WOF50_winter-Cytb_R2.fastq.gz
# WOF09_summer_mid-Cytb_R1.fastq.gz  WSH01_summer-12S_R1.fastq.gz
# WOF09_summer_mid-Cytb_R2.fastq.gz  WSH01_summer-12S_R2.fastq.gz
# WOF09_winter_mid-12S_R1.fastq.gz   WSH01_summer-Cytb_R1.fastq.gz
# WOF09_winter_mid-12S_R2.fastq.gz   WSH01_summer-Cytb_R2.fastq.gz
# WOF09_winter_mid-Cytb_R1.fastq.gz  WSH01_winter-12S_R1.fastq.gz
# WOF09_winter_mid-Cytb_R2.fastq.gz  WSH01_winter-12S_R2.fastq.gz
# WOF10_summer_0m-12S_R1.fastq.gz    WSH01_winter-Cytb_R1.fastq.gz
# WOF10_summer_0m-12S_R2.fastq.gz    WSH01_winter-Cytb_R2.fastq.gz
# WOF10_summer_0m-Cytb_R1.fastq.gz   WSH02_summer-12S_R1.fastq.gz
# WOF10_summer_0m-Cytb_R2.fastq.gz   WSH02_summer-12S_R2.fastq.gz
# WOF10_summer_mid-12S_R1.fastq.gz   WSH02_summer-Cytb_R1.fastq.gz
# WOF10_summer_mid-12S_R2.fastq.gz   WSH02_summer-Cytb_R2.fastq.gz
# WOF10_summer_mid-Cytb_R1.fastq.gz  WSH02_winter-12S_R1.fastq.gz
# WOF10_summer_mid-Cytb_R2.fastq.gz  WSH02_winter-12S_R2.fastq.gz
# WOF10_winter_mid-12S_R1.fastq.gz   WSH02_winter-Cytb_R1.fastq.gz
# WOF10_winter_mid-12S_R2.fastq.gz   WSH02_winter-Cytb_R2.fastq.gz
# WOF10_winter_mid-Cytb_R1.fastq.gz  WSH03_summer-12S_R1.fastq.gz
# WOF10_winter_mid-Cytb_R2.fastq.gz  WSH03_summer-12S_R2.fastq.gz
# WOF11_summer_0m-12S_R1.fastq.gz    WSH03_summer-Cytb_R1.fastq.gz
# WOF11_summer_0m-12S_R2.fastq.gz    WSH03_summer-Cytb_R2.fastq.gz
# WOF11_summer_0m-Cytb_R1.fastq.gz   WSH03_winter-12S_R1.fastq.gz
# WOF11_summer_0m-Cytb_R2.fastq.gz   WSH03_winter-12S_R2.fastq.gz
# WOF11_summer_60m-12S_R1.fastq.gz   WSH03_winter-Cytb_R1.fastq.gz
# WOF11_summer_60m-12S_R2.fastq.gz   WSH03_winter-Cytb_R2.fastq.gz
# WOF11_summer_60m-Cytb_R1.fastq.gz  WSH04_summer-12S_R1.fastq.gz
# WOF11_summer_60m-Cytb_R2.fastq.gz  WSH04_summer-12S_R2.fastq.gz
# WOF11_summer_mid-12S_R1.fastq.gz   WSH04_summer-Cytb_R1.fastq.gz
# WOF11_summer_mid-12S_R2.fastq.gz   WSH04_summer-Cytb_R2.fastq.gz
# WOF11_summer_mid-Cytb_R1.fastq.gz  WSH04_winter-12S_R1.fastq.gz
# WOF11_summer_mid-Cytb_R2.fastq.gz  WSH04_winter-12S_R2.fastq.gz
# WOF11_winter_mid-12S_R1.fastq.gz   WSH04_winter-Cytb_R1.fastq.gz
# WOF11_winter_mid-12S_R2.fastq.gz   WSH04_winter-Cytb_R2.fastq.gz
# WOF11_winter_mid-Cytb_R1.fastq.gz  WSH05_summer-12S_R1.fastq.gz
# WOF11_winter_mid-Cytb_R2.fastq.gz  WSH05_summer-12S_R2.fastq.gz
# WOF12_summer_0m-12S_R1.fastq.gz    WSH05_summer-Cytb_R1.fastq.gz
# WOF12_summer_0m-12S_R2.fastq.gz    WSH05_summer-Cytb_R2.fastq.gz
# WOF12_summer_0m-Cytb_R1.fastq.gz   WSH05_winter-12S_R1.fastq.gz
# WOF12_summer_0m-Cytb_R2.fastq.gz   WSH05_winter-12S_R2.fastq.gz
# WOF12_summer_40m-12S_R1.fastq.gz   WSH05_winter-Cytb_R1.fastq.gz
# WOF12_summer_40m-12S_R2.fastq.gz   WSH05_winter-Cytb_R2.fastq.gz
# WOF12_summer_40m-Cytb_R1.fastq.gz  WSH06_summer-12S_R1.fastq.gz
# WOF12_summer_40m-Cytb_R2.fastq.gz  WSH06_summer-12S_R2.fastq.gz
# WOF12_summer_mid-12S_R1.fastq.gz   WSH06_summer-Cytb_R1.fastq.gz
# WOF12_summer_mid-12S_R2.fastq.gz   WSH06_summer-Cytb_R2.fastq.gz
# WOF12_summer_mid-Cytb_R1.fastq.gz  WSH06_winter-12S_R1.fastq.gz
# WOF12_summer_mid-Cytb_R2.fastq.gz  WSH06_winter-12S_R2.fastq.gz
# WOF12_winter_mid-12S_R1.fastq.gz   WSH06_winter-Cytb_R1.fastq.gz
# WOF12_winter_mid-12S_R2.fastq.gz   WSH06_winter-Cytb_R2.fastq.gz
# WOF12_winter_mid-Cytb_R1.fastq.gz  WSH07_summer-12S_R1.fastq.gz
# WOF12_winter_mid-Cytb_R2.fastq.gz  WSH07_summer-12S_R2.fastq.gz
# WOF13_summer_0m-12S_R1.fastq.gz    WSH07_summer-Cytb_R1.fastq.gz
# WOF13_summer_0m-12S_R2.fastq.gz    WSH07_summer-Cytb_R2.fastq.gz
# WOF13_summer_0m-Cytb_R1.fastq.gz   WSH07_winter-12S_R1.fastq.gz
# WOF13_summer_0m-Cytb_R2.fastq.gz   WSH07_winter-12S_R2.fastq.gz
# WOF13_summer_40m-12S_R1.fastq.gz   WSH07_winter-Cytb_R1.fastq.gz
# WOF13_summer_40m-12S_R2.fastq.gz   WSH07_winter-Cytb_R2.fastq.gz
# WOF13_summer_40m-Cytb_R1.fastq.gz  WSH08_summer-12S_R1.fastq.gz
# WOF13_summer_40m-Cytb_R2.fastq.gz  WSH08_summer-12S_R2.fastq.gz
# WOF13_summer_mid-12S_R1.fastq.gz   WSH08_summer-Cytb_R1.fastq.gz
# WOF13_summer_mid-12S_R2.fastq.gz   WSH08_summer-Cytb_R2.fastq.gz
# WOF13_summer_mid-Cytb_R1.fastq.gz  WSH08_winter-12S_R1.fastq.gz
# WOF13_summer_mid-Cytb_R2.fastq.gz  WSH08_winter-12S_R2.fastq.gz
# WOF13_winter_mid-12S_R1.fastq.gz   WSH08_winter-Cytb_R1.fastq.gz
# WOF13_winter_mid-12S_R2.fastq.gz   WSH08_winter-Cytb_R2.fastq.gz
# WOF13_winter_mid-Cytb_R1.fastq.gz  WSH09_summer-12S_R1.fastq.gz
# WOF13_winter_mid-Cytb_R2.fastq.gz  WSH09_summer-12S_R2.fastq.gz
# WOF14_summer_0m-12S_R1.fastq.gz    WSH09_summer-Cytb_R1.fastq.gz
# WOF14_summer_0m-12S_R2.fastq.gz    WSH09_summer-Cytb_R2.fastq.gz
# WOF14_summer_0m-Cytb_R1.fastq.gz   WSH09_winter-12S_R1.fastq.gz
# WOF14_summer_0m-Cytb_R2.fastq.gz   WSH09_winter-12S_R2.fastq.gz
# WOF14_summer_30m-12S_R1.fastq.gz   WSH09_winter-Cytb_R1.fastq.gz
# WOF14_summer_30m-12S_R2.fastq.gz   WSH09_winter-Cytb_R2.fastq.gz
# WOF14_summer_30m-Cytb_R1.fastq.gz  WSH10_summer-12S_R1.fastq.gz
# WOF14_summer_30m-Cytb_R2.fastq.gz  WSH10_summer-12S_R2.fastq.gz
# WOF14_summer_mid-12S_R1.fastq.gz   WSH10_summer-Cytb_R1.fastq.gz
# WOF14_summer_mid-12S_R2.fastq.gz   WSH10_summer-Cytb_R2.fastq.gz
# WOF14_summer_mid-Cytb_R1.fastq.gz  WSH10_winter-12S_R1.fastq.gz
# WOF14_summer_mid-Cytb_R2.fastq.gz  WSH10_winter-12S_R2.fastq.gz
# WOF14_winter_mid-12S_R1.fastq.gz   WSH10_winter-Cytb_R1.fastq.gz
# WOF14_winter_mid-12S_R2.fastq.gz   WSH10_winter-Cytb_R2.fastq.gz
# WOF14_winter_mid-Cytb_R1.fastq.gz  WSH11_summer-12S_R1.fastq.gz
# WOF14_winter_mid-Cytb_R2.fastq.gz  WSH11_summer-12S_R2.fastq.gz
# WOF15_summer_mid-12S_R1.fastq.gz   WSH11_summer-Cytb_R1.fastq.gz
# WOF15_summer_mid-12S_R2.fastq.gz   WSH11_summer-Cytb_R2.fastq.gz
# WOF15_summer_mid-Cytb_R1.fastq.gz  WSH11_winter-12S_R1.fastq.gz
# WOF15_summer_mid-Cytb_R2.fastq.gz  WSH11_winter-12S_R2.fastq.gz
# WOF15_winter_mid-12S_R1.fastq.gz   WSH11_winter-Cytb_R1.fastq.gz
# WOF15_winter_mid-12S_R2.fastq.gz   WSH11_winter-Cytb_R2.fastq.gz
# WOF15_winter_mid-Cytb_R1.fastq.gz  WSH12_summer-12S_R1.fastq.gz
# WOF15_winter_mid-Cytb_R2.fastq.gz  WSH12_summer-12S_R2.fastq.gz
# WOF17_summer-12S_R1.fastq.gz	   WSH12_summer-Cytb_R1.fastq.gz
# WOF17_summer-12S_R2.fastq.gz	   WSH12_summer-Cytb_R2.fastq.gz
# WOF17_summer-Cytb_R1.fastq.gz	   WSH12_winter-12S_R1.fastq.gz
# WOF17_summer-Cytb_R2.fastq.gz	   WSH12_winter-12S_R2.fastq.gz
# WOF17_winter-12S_R1.fastq.gz	   WSH12_winter-Cytb_R1.fastq.gz
# WOF17_winter-12S_R2.fastq.gz	   WSH12_winter-Cytb_R2.fastq.gz
# WOF17_winter-Cytb_R1.fastq.gz	   WSH13_summer-12S_R1.fastq.gz
# WOF17_winter-Cytb_R2.fastq.gz	   WSH13_summer-12S_R2.fastq.gz
# WOF18_summer-12S_R1.fastq.gz	   WSH13_summer-Cytb_R1.fastq.gz
# WOF18_summer-12S_R2.fastq.gz	   WSH13_summer-Cytb_R2.fastq.gz
# WOF18_summer-Cytb_R1.fastq.gz	   WSH13_winter-12S_R1.fastq.gz
# WOF18_summer-Cytb_R2.fastq.gz	   WSH13_winter-12S_R2.fastq.gz
# WOF18_winter-12S_R1.fastq.gz	   WSH13_winter-Cytb_R1.fastq.gz
# WOF18_winter-12S_R2.fastq.gz	   WSH13_winter-Cytb_R2.fastq.gz
# WOF18_winter-Cytb_R1.fastq.gz	   WSH14_summer-12S_R1.fastq.gz
# WOF18_winter-Cytb_R2.fastq.gz	   WSH14_summer-12S_R2.fastq.gz
# WOF19_summer-12S_R1.fastq.gz	   WSH14_summer-Cytb_R1.fastq.gz
# WOF19_summer-12S_R2.fastq.gz	   WSH14_summer-Cytb_R2.fastq.gz
# WOF19_summer-Cytb_R1.fastq.gz	   WSH14_winter-12S_R1.fastq.gz
# WOF19_summer-Cytb_R2.fastq.gz	   WSH14_winter-12S_R2.fastq.gz
# WOF19_winter-12S_R1.fastq.gz	   WSH14_winter-Cytb_R1.fastq.gz
# WOF19_winter-12S_R2.fastq.gz	   WSH14_winter-Cytb_R2.fastq.gz
# WOF19_winter-Cytb_R1.fastq.gz	   WSH15_summer-12S_R1.fastq.gz
# WOF19_winter-Cytb_R2.fastq.gz	   WSH15_summer-12S_R2.fastq.gz
# WOF20_summer-12S_R1.fastq.gz	   WSH15_summer-Cytb_R1.fastq.gz
# WOF20_summer-12S_R2.fastq.gz	   WSH15_summer-Cytb_R2.fastq.gz
# WOF20_summer-Cytb_R1.fastq.gz	   WSH15_winter-12S_R1.fastq.gz
# WOF20_summer-Cytb_R2.fastq.gz	   WSH15_winter-12S_R2.fastq.gz
# WOF20_winter-12S_R1.fastq.gz	   WSH15_winter-Cytb_R1.fastq.gz
# WOF20_winter-12S_R2.fastq.gz	   WSH15_winter-Cytb_R2.fastq.gz
# WOF20_winter-Cytb_R1.fastq.gz	   WSH16_summer-12S_R1.fastq.gz
# WOF20_winter-Cytb_R2.fastq.gz	   WSH16_summer-12S_R2.fastq.gz
# WOF21_summer-12S_R1.fastq.gz	   WSH16_summer-Cytb_R1.fastq.gz
# WOF21_summer-12S_R2.fastq.gz	   WSH16_summer-Cytb_R2.fastq.gz
# WOF21_summer-Cytb_R1.fastq.gz	   WSH16_winter-12S_R1.fastq.gz
# WOF21_summer-Cytb_R2.fastq.gz	   WSH16_winter-12S_R2.fastq.gz
# WOF21_winter-12S_R1.fastq.gz	   WSH16_winter-Cytb_R1.fastq.gz
# WOF21_winter-12S_R2.fastq.gz	   WSH16_winter-Cytb_R2.fastq.gz
# WOF21_winter-Cytb_R1.fastq.gz	   WSH17_summer-12S_R1.fastq.gz
# WOF21_winter-Cytb_R2.fastq.gz	   WSH17_summer-12S_R2.fastq.gz
# WOF22_summer-12S_R1.fastq.gz	   WSH17_summer-Cytb_R1.fastq.gz
# WOF22_summer-12S_R2.fastq.gz	   WSH17_summer-Cytb_R2.fastq.gz
# WOF22_summer-Cytb_R1.fastq.gz	   WSH17_winter-12S_R1.fastq.gz
# WOF22_summer-Cytb_R2.fastq.gz	   WSH17_winter-12S_R2.fastq.gz
# WOF22_winter-12S_R1.fastq.gz	   WSH17_winter-Cytb_R1.fastq.gz
# WOF22_winter-12S_R2.fastq.gz	   WSH17_winter-Cytb_R2.fastq.gz
# WOF22_winter-Cytb_R1.fastq.gz	   WSH18_summer-12S_R1.fastq.gz
# WOF22_winter-Cytb_R2.fastq.gz	   WSH18_summer-12S_R2.fastq.gz
# WOF23_summer-12S_R1.fastq.gz	   WSH18_summer-Cytb_R1.fastq.gz
# WOF23_summer-12S_R2.fastq.gz	   WSH18_summer-Cytb_R2.fastq.gz
# WOF23_summer-Cytb_R1.fastq.gz	   WSH18_winter-12S_R1.fastq.gz
# WOF23_summer-Cytb_R2.fastq.gz	   WSH18_winter-12S_R2.fastq.gz
# WOF23_winter-12S_R1.fastq.gz	   WSH18_winter-Cytb_R1.fastq.gz
# WOF23_winter-12S_R2.fastq.gz	   WSH18_winter-Cytb_R2.fastq.gz
# WOF23_winter-Cytb_R1.fastq.gz	   WSH19_winter-12S_R1.fastq.gz
# WOF23_winter-Cytb_R2.fastq.gz	   WSH19_winter-12S_R2.fastq.gz
# WOF24_summer-12S_R1.fastq.gz	   WSH19_winter-Cytb_R1.fastq.gz
# WOF24_summer-12S_R2.fastq.gz	   WSH19_winter-Cytb_R2.fastq.gz
# WOF24_summer-Cytb_R1.fastq.gz	   WSH20_summer-12S_R1.fastq.gz
# WOF24_summer-Cytb_R2.fastq.gz	   WSH20_summer-12S_R2.fastq.gz
# WOF24_winter-12S_R1.fastq.gz	   WSH20_summer-Cytb_R1.fastq.gz
# WOF24_winter-12S_R2.fastq.gz	   WSH20_summer-Cytb_R2.fastq.gz
# WOF24_winter-Cytb_R1.fastq.gz	   WSH20_winter-12S_R1.fastq.gz
# WOF24_winter-Cytb_R2.fastq.gz	   WSH20_winter-12S_R2.fastq.gz
# WOF25_summer_mid-12S_R1.fastq.gz   WSH20_winter-Cytb_R1.fastq.gz
# WOF25_summer_mid-12S_R2.fastq.gz   WSH20_winter-Cytb_R2.fastq.gz
# WOF25_summer_mid-Cytb_R1.fastq.gz  WSH21_summer-12S_R1.fastq.gz
# WOF25_summer_mid-Cytb_R2.fastq.gz  WSH21_summer-12S_R2.fastq.gz
# WOF25_winter_mid-12S_R1.fastq.gz   WSH21_summer-Cytb_R1.fastq.gz
# WOF25_winter_mid-12S_R2.fastq.gz   WSH21_summer-Cytb_R2.fastq.gz
# WOF25_winter_mid-Cytb_R1.fastq.gz  WSH21_winter-12S_R1.fastq.gz
# WOF25_winter_mid-Cytb_R2.fastq.gz  WSH21_winter-12S_R2.fastq.gz
# WOF26_summer_0m-12S_R1.fastq.gz    WSH21_winter-Cytb_R1.fastq.gz
# WOF26_summer_0m-12S_R2.fastq.gz    WSH21_winter-Cytb_R2.fastq.gz
# WOF26_summer_0m-Cytb_R1.fastq.gz   WSH22_summer-12S_R1.fastq.gz
# WOF26_summer_0m-Cytb_R2.fastq.gz   WSH22_summer-12S_R2.fastq.gz
# WOF26_summer_25m-12S_R1.fastq.gz   WSH22_summer-Cytb_R1.fastq.gz
# WOF26_summer_25m-12S_R2.fastq.gz   WSH22_summer-Cytb_R2.fastq.gz
# WOF26_summer_25m-Cytb_R1.fastq.gz  WSH22_winter-12S_R1.fastq.gz
# WOF26_summer_25m-Cytb_R2.fastq.gz  WSH22_winter-12S_R2.fastq.gz
# WOF26_summer_mid-12S_R1.fastq.gz   WSH22_winter-Cytb_R1.fastq.gz
# WOF26_summer_mid-12S_R2.fastq.gz   WSH22_winter-Cytb_R2.fastq.gz
# WOF26_summer_mid-Cytb_R1.fastq.gz  WSH23_summer-12S_R1.fastq.gz
# WOF26_summer_mid-Cytb_R2.fastq.gz  WSH23_summer-12S_R2.fastq.gz
# WOF26_winter_mid-12S_R1.fastq.gz   WSH23_summer-Cytb_R1.fastq.gz
# WOF26_winter_mid-12S_R2.fastq.gz   WSH23_summer-Cytb_R2.fastq.gz
# WOF26_winter_mid-Cytb_R1.fastq.gz  WSH23_winter-12S_R1.fastq.gz
# WOF26_winter_mid-Cytb_R2.fastq.gz  WSH23_winter-12S_R2.fastq.gz
# WOF27_summer_0m-12S_R1.fastq.gz    WSH23_winter-Cytb_R1.fastq.gz
# WOF27_summer_0m-12S_R2.fastq.gz    WSH23_winter-Cytb_R2.fastq.gz
# WOF27_summer_0m-Cytb_R1.fastq.gz   WSH24_summer-12S_R1.fastq.gz
# WOF27_summer_0m-Cytb_R2.fastq.gz   WSH24_summer-12S_R2.fastq.gz
# WOF27_summer_30m-12S_R1.fastq.gz   WSH24_summer-Cytb_R1.fastq.gz
# WOF27_summer_30m-12S_R2.fastq.gz   WSH24_summer-Cytb_R2.fastq.gz
# WOF27_summer_30m-Cytb_R1.fastq.gz  WSH24_winter-12S_R1.fastq.gz
# WOF27_summer_30m-Cytb_R2.fastq.gz  WSH24_winter-12S_R2.fastq.gz
# WOF27_summer_mid-12S_R1.fastq.gz   WSH24_winter-Cytb_R1.fastq.gz
# WOF27_summer_mid-12S_R2.fastq.gz   WSH24_winter-Cytb_R2.fastq.gz
# WOF27_summer_mid-Cytb_R1.fastq.gz  WSH25_summer-12S_R1.fastq.gz
# WOF27_summer_mid-Cytb_R2.fastq.gz  WSH25_summer-12S_R2.fastq.gz
# WOF27_winter_mid-12S_R1.fastq.gz   WSH25_summer-Cytb_R1.fastq.gz
# WOF27_winter_mid-12S_R2.fastq.gz   WSH25_summer-Cytb_R2.fastq.gz
# WOF27_winter_mid-Cytb_R1.fastq.gz  WSH25_winter-12S_R1.fastq.gz
# WOF27_winter_mid-Cytb_R2.fastq.gz  WSH25_winter-12S_R2.fastq.gz
# WOF28_summer_0m-12S_R1.fastq.gz    WSH25_winter-Cytb_R1.fastq.gz
# WOF28_summer_0m-12S_R2.fastq.gz    WSH25_winter-Cytb_R2.fastq.gz
# WOF28_summer_0m-Cytb_R1.fastq.gz   WSH26_summer-12S_R1.fastq.gz
# WOF28_summer_0m-Cytb_R2.fastq.gz   WSH26_summer-12S_R2.fastq.gz
# WOF28_summer_40m-12S_R1.fastq.gz   WSH26_summer-Cytb_R1.fastq.gz
# WOF28_summer_40m-12S_R2.fastq.gz   WSH26_summer-Cytb_R2.fastq.gz
# WOF28_summer_40m-Cytb_R1.fastq.gz  WSH26_winter-12S_R1.fastq.gz
# WOF28_summer_40m-Cytb_R2.fastq.gz  WSH26_winter-12S_R2.fastq.gz
# WOF28_summer_mid-12S_R1.fastq.gz   WSH26_winter-Cytb_R1.fastq.gz
# WOF28_summer_mid-12S_R2.fastq.gz   WSH26_winter-Cytb_R2.fastq.gz
# WOF28_summer_mid-Cytb_R1.fastq.gz  WSH27_summer-12S_R1.fastq.gz
# WOF28_summer_mid-Cytb_R2.fastq.gz  WSH27_summer-12S_R2.fastq.gz
# WOF28_winter_mid-12S_R1.fastq.gz   WSH27_summer-Cytb_R1.fastq.gz
# WOF28_winter_mid-12S_R2.fastq.gz   WSH27_summer-Cytb_R2.fastq.gz
# WOF28_winter_mid-Cytb_R1.fastq.gz  WSH27_winter-12S_R1.fastq.gz
# WOF28_winter_mid-Cytb_R2.fastq.gz  WSH27_winter-12S_R2.fastq.gz
# WOF29_summer_mid-12S_R1.fastq.gz   WSH27_winter-Cytb_R1.fastq.gz
# WOF29_summer_mid-12S_R2.fastq.gz   WSH27_winter-Cytb_R2.fastq.gz
# WOF29_summer_mid-Cytb_R1.fastq.gz  WSH28_summer-12S_R1.fastq.gz
# WOF29_summer_mid-Cytb_R2.fastq.gz  WSH28_summer-12S_R2.fastq.gz
# WOF30_summer_0m-12S_R1.fastq.gz    WSH28_summer-Cytb_R1.fastq.gz
# WOF30_summer_0m-12S_R2.fastq.gz    WSH28_summer-Cytb_R2.fastq.gz
# WOF30_summer_0m-Cytb_R1.fastq.gz   WSH28_winter-12S_R1.fastq.gz
# WOF30_summer_0m-Cytb_R2.fastq.gz   WSH28_winter-12S_R2.fastq.gz
# WOF30_summer_30m-12S_R1.fastq.gz   WSH28_winter-Cytb_R1.fastq.gz
# WOF30_summer_30m-12S_R2.fastq.gz   WSH28_winter-Cytb_R2.fastq.gz
# WOF30_summer_30m-Cytb_R1.fastq.gz  WSH29_summer-12S_R1.fastq.gz
# WOF30_summer_30m-Cytb_R2.fastq.gz  WSH29_summer-12S_R2.fastq.gz
# WOF30_summer_mid-12S_R1.fastq.gz   WSH29_summer-Cytb_R1.fastq.gz
# WOF30_summer_mid-12S_R2.fastq.gz   WSH29_summer-Cytb_R2.fastq.gz
# WOF30_summer_mid-Cytb_R1.fastq.gz  WSH29_winter-12S_R1.fastq.gz
# WOF30_summer_mid-Cytb_R2.fastq.gz  WSH29_winter-12S_R2.fastq.gz
# WOF30_winter_mid-12S_R1.fastq.gz   WSH29_winter-Cytb_R1.fastq.gz
# WOF30_winter_mid-12S_R2.fastq.gz   WSH29_winter-Cytb_R2.fastq.gz
# WOF30_winter_mid-Cytb_R1.fastq.gz  WSH30_summer-12S_R1.fastq.gz
# WOF30_winter_mid-Cytb_R2.fastq.gz  WSH30_summer-12S_R2.fastq.gz
# WOF31_summer_0m-12S_R1.fastq.gz    WSH30_summer-Cytb_R1.fastq.gz
# WOF31_summer_0m-12S_R2.fastq.gz    WSH30_summer-Cytb_R2.fastq.gz
# WOF31_summer_0m-Cytb_R1.fastq.gz   WSH30_winter-12S_R1.fastq.gz
# WOF31_summer_0m-Cytb_R2.fastq.gz   WSH30_winter-12S_R2.fastq.gz
# WOF31_summer_30m-12S_R1.fastq.gz   WSH30_winter-Cytb_R1.fastq.gz
# WOF31_summer_30m-12S_R2.fastq.gz   WSH30_winter-Cytb_R2.fastq.gz
# WOF31_summer_30m-Cytb_R1.fastq.gz  WSH31_summer-12S_R1.fastq.gz
# WOF31_summer_30m-Cytb_R2.fastq.gz  WSH31_summer-12S_R2.fastq.gz
# WOF31_summer_mid-12S_R1.fastq.gz   WSH31_summer-Cytb_R1.fastq.gz
# WOF31_summer_mid-12S_R2.fastq.gz   WSH31_summer-Cytb_R2.fastq.gz
# WOF31_summer_mid-Cytb_R1.fastq.gz  WSH31_winter-12S_R1.fastq.gz
# WOF31_summer_mid-Cytb_R2.fastq.gz  WSH31_winter-12S_R2.fastq.gz
# WOF31_winter_mid-12S_R1.fastq.gz   WSH31_winter-Cytb_R1.fastq.gz
# WOF31_winter_mid-12S_R2.fastq.gz   WSH31_winter-Cytb_R2.fastq.gz
# WOF31_winter_mid-Cytb_R1.fastq.gz  WSH32_summer-12S_R1.fastq.gz
# WOF31_winter_mid-Cytb_R2.fastq.gz  WSH32_summer-12S_R2.fastq.gz
# WOF32_summer_mid-12S_R1.fastq.gz   WSH32_summer-Cytb_R1.fastq.gz
# WOF32_summer_mid-12S_R2.fastq.gz   WSH32_summer-Cytb_R2.fastq.gz
# WOF32_summer_mid-Cytb_R1.fastq.gz  WSH32_winter-12S_R1.fastq.gz
# WOF32_summer_mid-Cytb_R2.fastq.gz  WSH32_winter-12S_R2.fastq.gz
# WOF32_winter_mid-12S_R1.fastq.gz   WSH32_winter-Cytb_R1.fastq.gz
# WOF32_winter_mid-12S_R2.fastq.gz   WSH32_winter-Cytb_R2.fastq.gz
# WOF32_winter_mid-Cytb_R1.fastq.gz  WSH33_summer-12S_R1.fastq.gz
# WOF32_winter_mid-Cytb_R2.fastq.gz  WSH33_summer-12S_R2.fastq.gz
# WOF33_summer-12S_R1.fastq.gz	   WSH33_summer-Cytb_R1.fastq.gz
# WOF33_summer-12S_R2.fastq.gz	   WSH33_summer-Cytb_R2.fastq.gz
# WOF33_summer-Cytb_R1.fastq.gz	   WSH33_winter-12S_R1.fastq.gz
# WOF33_summer-Cytb_R2.fastq.gz	   WSH33_winter-12S_R2.fastq.gz
# WOF33_winter-12S_R1.fastq.gz	   WSH33_winter-Cytb_R1.fastq.gz
# WOF33_winter-12S_R2.fastq.gz	   WSH33_winter-Cytb_R2.fastq.gz
# WOF33_winter-Cytb_R1.fastq.gz	   WSH34_summer-12S_R1.fastq.gz
# WOF33_winter-Cytb_R2.fastq.gz	   WSH34_summer-12S_R2.fastq.gz
# WOF34_summer-12S_R1.fastq.gz	   WSH34_summer-Cytb_R1.fastq.gz
# WOF34_summer-12S_R2.fastq.gz	   WSH34_summer-Cytb_R2.fastq.gz
# WOF34_summer-Cytb_R1.fastq.gz	   WSH34_winter-12S_R1.fastq.gz
# WOF34_summer-Cytb_R2.fastq.gz	   WSH34_winter-12S_R2.fastq.gz
# WOF34_winter-12S_R1.fastq.gz	   WSH34_winter-Cytb_R1.fastq.gz
# WOF34_winter-12S_R2.fastq.gz	   WSH34_winter-Cytb_R2.fastq.gz
# WOF34_winter-Cytb_R1.fastq.gz	   WSH35_summer-12S_R1.fastq.gz
# WOF34_winter-Cytb_R2.fastq.gz	   WSH35_summer-12S_R2.fastq.gz
# WOF35_winter-12S_R1.fastq.gz	   WSH35_summer-Cytb_R1.fastq.gz
# WOF35_winter-12S_R2.fastq.gz	   WSH35_summer-Cytb_R2.fastq.gz
# WOF35_winter-Cytb_R1.fastq.gz	   WSH35_winter-12S_R1.fastq.gz
# WOF35_winter-Cytb_R2.fastq.gz	   WSH35_winter-12S_R2.fastq.gz
# WOF36_summer-12S_R1.fastq.gz	   WSH35_winter-Cytb_R1.fastq.gz
# WOF36_summer-12S_R2.fastq.gz	   WSH35_winter-Cytb_R2.fastq.gz
# WOF36_summer-Cytb_R1.fastq.gz	   WSH36_summer-12S_R1.fastq.gz
# WOF36_summer-Cytb_R2.fastq.gz	   WSH36_summer-12S_R2.fastq.gz
# WOF36_winter-12S_R1.fastq.gz	   WSH36_summer-Cytb_R1.fastq.gz
# WOF36_winter-12S_R2.fastq.gz	   WSH36_summer-Cytb_R2.fastq.gz
# WOF36_winter-Cytb_R1.fastq.gz	   WSH36_winter-12S_R1.fastq.gz
# WOF36_winter-Cytb_R2.fastq.gz	   WSH36_winter-12S_R2.fastq.gz
# WOF37_summer-12S_R1.fastq.gz	   WSH36_winter-Cytb_R1.fastq.gz
# WOF37_summer-12S_R2.fastq.gz	   WSH36_winter-Cytb_R2.fastq.gz
# WOF37_summer-Cytb_R1.fastq.gz	   WSH37_summer-12S_R1.fastq.gz
# WOF37_summer-Cytb_R2.fastq.gz	   WSH37_summer-12S_R2.fastq.gz
# WOF37_winter-12S_R1.fastq.gz	   WSH37_summer-Cytb_R1.fastq.gz
# WOF37_winter-12S_R2.fastq.gz	   WSH37_summer-Cytb_R2.fastq.gz
# WOF37_winter-Cytb_R1.fastq.gz	   WSH37_winter-12S_R1.fastq.gz
# WOF37_winter-Cytb_R2.fastq.gz	   WSH37_winter-12S_R2.fastq.gz
# WOF38_summer-12S_R1.fastq.gz	   WSH37_winter-Cytb_R1.fastq.gz
# WOF38_summer-12S_R2.fastq.gz	   WSH37_winter-Cytb_R2.fastq.gz
# WOF38_summer-Cytb_R1.fastq.gz	   WSH38_summer-12S_R1.fastq.gz
# WOF38_summer-Cytb_R2.fastq.gz	   WSH38_summer-12S_R2.fastq.gz
# WOF38_winter-12S_R1.fastq.gz	   WSH38_summer-Cytb_R1.fastq.gz
# WOF38_winter-12S_R2.fastq.gz	   WSH38_summer-Cytb_R2.fastq.gz
# WOF38_winter-Cytb_R1.fastq.gz	   WSH38_winter-12S_R1.fastq.gz
# WOF38_winter-Cytb_R2.fastq.gz	   WSH38_winter-12S_R2.fastq.gz
# WOF39_summer-12S_R1.fastq.gz	   WSH38_winter-Cytb_R1.fastq.gz
# WOF39_summer-12S_R2.fastq.gz	   WSH38_winter-Cytb_R2.fastq.gz
# WOF39_summer-Cytb_R1.fastq.gz	   WSH39_summer-12S_R1.fastq.gz
# WOF39_summer-Cytb_R2.fastq.gz	   WSH39_summer-12S_R2.fastq.gz
# WOF39_winter-12S_R1.fastq.gz	   WSH39_summer-Cytb_R1.fastq.gz
# WOF39_winter-12S_R2.fastq.gz	   WSH39_summer-Cytb_R2.fastq.gz
# WOF39_winter-Cytb_R1.fastq.gz	   WSH39_winter-12S_R1.fastq.gz
# WOF39_winter-Cytb_R2.fastq.gz	   WSH39_winter-12S_R2.fastq.gz
# WOF40_summer-12S_R1.fastq.gz	   WSH39_winter-Cytb_R1.fastq.gz
# WOF40_summer-12S_R2.fastq.gz	   WSH39_winter-Cytb_R2.fastq.gz
# WOF40_summer-Cytb_R1.fastq.gz	   WSH40_summer-12S_R1.fastq.gz
# WOF40_summer-Cytb_R2.fastq.gz	   WSH40_summer-12S_R2.fastq.gz
# WOF40_winter-12S_R1.fastq.gz	   WSH40_summer-Cytb_R1.fastq.gz
# WOF40_winter-12S_R2.fastq.gz	   WSH40_summer-Cytb_R2.fastq.gz
# WOF40_winter-Cytb_R1.fastq.gz	   WSH40_winter-12S_R1.fastq.gz
# WOF40_winter-Cytb_R2.fastq.gz	   WSH40_winter-12S_R2.fastq.gz
# WOF41_summer-12S_R1.fastq.gz	   WSH40_winter-Cytb_R1.fastq.gz
# WOF41_summer-12S_R2.fastq.gz	   WSH40_winter-Cytb_R2.fastq.gz
